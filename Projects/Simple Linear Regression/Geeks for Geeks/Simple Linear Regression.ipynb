# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##### first of all we have to remove the nan values from the dataset

# %%
df.dropna(inplace = True)
df
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [699 rows x 2 columns]

# %% [markdown]
# We have to split the data into training set and test set
# where we have x training sets as well as y training sets
# and we also maintain x_test,y_test sets to test the model accuracy

# %%
x_train = df['x'][:500].values
y_train = df['y'][:500].values

# %%
plt.scatter(x_train,y_train,marker=".")

# %%
x_test = df['x'][500:].values.reshape(-1,1)
y_test = df['y'][500:].values.reshape(-1,1)

# %%
plt.scatter(x_test,y_test,marker='.',color="red")

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
x_train = x_train.reshape(-1,1)
y_train = y_train.reshape(-1,1)

# %% [markdown]
# y_pred contains the predicted values of the model and now we have to
# compare and conclude that if our values are atleast near to the y_train or not
# by visualizing the data

# %%
lm.fit(x_train,y_train)
y_pred = lm.predict(x_test)

# %%
plt.scatter(x_test,y_test,marker=".")
plt.plot(x_test,y_pred,color='red')

# %%
m = lm.coef_.flatten()
b = lm.intercept_.flatten()

# %%
eq = f"y={m}*x+{b}"
eq
# Out:
# 'y=[1.0009993]*x+[-0.23603461]'

# %%
np.append(y_test,y_pred,axis=1)
# Out:
# array([[  7.68202459,   4.76896187],
#        [ 61.01858089,  60.82492252],
#        [ 53.60562216,  46.81093236],
#        [ 94.47728801,  97.86189652],
#        [ 27.9645947 ,  29.7939443 ],
#        [ 62.55662585,  62.82692111],
#        [  1.40625441,  -0.23603461],
#        [101.7003412 ,  99.86389511],
#        [ 13.84973988,  17.78195274],
#        [ 28.99769315,  29.7939443 ],
#        [ 99.04315693,  97.86189652],
#        [ 15.56135514,  15.77995414],
#        [ 24.63528393,  21.78594992],
#        [ 53.98393374,  54.81892673],
#        [ 42.91449728,  42.80693517],
#        [ 74.29662112,  74.83891268],
#        [ 91.17012883,  90.85490143],
#        [ 49.42440876,  45.80993306],
#        [ 82.47683519,  84.84890565],
#        [ 56.15303953,  54.81892673],
#        [ 37.17063131,  35.79994009],
#        [ 46.36928662,  48.81293095],
#        [ 97.02383456,  93.85789933],
#        [ 40.83182104,  42.80693517],
#        [ 24.08498313,  21.78594992],
# ...

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mse = mean_squared_error(y_pred,y_test)
rmse = mse**0.5

# %%
rmse
# Out:
# 2.83373103731377

# %%
r2_score(y_pred,y_test)
# Out:
# 0.9908056798249666

# %%
from sklearn.externals import joblib
joblib.dump(lm, 'lm_regressor.pkl')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 from sklearn.externals import joblib
#       2 joblib.dump(lm, 'lm_regressor.pkl')
#
# ImportError: cannot import name 'joblib' from 'sklearn.externals' (C:\Users\91630\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\externals\__init__.py)
