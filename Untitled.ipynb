# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-100,100)

# %%
y = x**2

# %%
plt.plot(x,y)

# %%
plt.plot(x,-x**2)

# %%
plt.plot(x,x**3)

# %%
eq = "y = (x+2)*((x-1)**2)*(x-4)"
eq
# Out:
# 'y = (x+2)*((x-1)**2)*(x-4)'

# %%
x = np.arange(1,10)

# %%
y = eval("(x+2)*((x-1)**2)*(x-4)")
y
# Out:
# array([   0,   -8,  -20,    0,  112,  400,  972, 1960, 3520])

# %%
plt.plot(x,y)
